# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
import pandas as pd
from PyPDF2 import PdfFileReader
from io import BytesIO
from snowflake.snowpark import types as T
from snowflake.snowpark.files import SnowflakeFile
from snowflake.snowpark.types import StringType
from snowflake.snowpark import Session
from snowflake.snowpark.types import StringType, StructField, StructType

# %%
session = Session.builder.getOrCreate()
# Out:
# /opt/anaconda3/envs/RAG_DEMO/lib/python3.10/site-packages/snowflake/connector/config_manager.py:344: UserWarning: Bad owner or permissions on /Users/cromano/.snowflake/config.toml.
#  * To change owner, run `chown $USER "/Users/cromano/.snowflake/config.toml"`.
#  * To restrict permissions, run `chmod 0600 "/Users/cromano/.snowflake/config.toml"`.
#
#   warn(f"Bad owner or permissions on {str(filep)}{chmod_message}")

# %%
session.use_database('cromano')
session.use_schema('demo')

# %%
session.sql("create stage if not exists RAG DIRECTORY = ( ENABLE = TRUE)").collect()
# Out:
# [Row(status='RAG already exists, statement succeeded.')]

# %%
session.file.put("documents/*.pdf", "@RAG", auto_compress=False, overwrite=True)
# Out:
# [PutResult(source='SnowflakeEarningsCall1123.pdf', target='SnowflakeEarningsCall1123.pdf', source_size=313773, target_size=313776, source_compression='NONE', target_compression='NONE', status='UPLOADED', message='')]

# %%
def readpdf(file_path):
    whole_text = ""
    with SnowflakeFile.open(file_path, "rb") as file:
        f = BytesIO(file.readall())
        pdf_reader = PdfFileReader(f)
        whole_text = ""
        for page in pdf_reader.pages:
            whole_text += page.extract_text()
    return whole_text

# %%
# Register the UDF.
session.udf.register(
    func=readpdf,
    return_type=StringType(),
    input_types=[StringType()],
    is_permanent=True,
    name="SNOWPARK_PDF",
    replace=True,
    packages=["snowflake-snowpark-python", "pypdf2", "PyCryptodome"],
    stage_location="RAG",
)

# %%
session.sql(
    """
CREATE OR REPLACE TABLE RAW_TEXT AS
SELECT
    relative_path
    , file_url
    , snowpark_pdf(build_scoped_file_url(@RAG, relative_path)) as raw_text
from directory(@RAG)
            """
).collect()
# Out:
# [Row(status='Table RAW_TEXT successfully created.')]

# %%
session.table("RAW_TEXT").show()
# Out:
# -------------------------------------------------------------------------------------------------------------------------------------------
# |"RELATIVE_PATH"                |"FILE_URL"                                          |"RAW_TEXT"                                          |
# -------------------------------------------------------------------------------------------------------------------------------------------
# |SnowflakeEarningsCall1123.pdf  |https://xwb80589.snowflakecomputing.com/api/fil...  | Corrected Transcript                               |
# |                               |                                                    |                                                    |
# |                               |                                                    |                                                    |
# |                               |                                                    |1-877-FACTSET   www.callstreet.com  Total Pages...  |
# |                               |                                                    |Copyright © 2001 -2023  FactSet  CallStreet, LLC    |
# |                               |                                                    |                                                    |
# |                               |                                                    |29-Nov-2023                                         |
# |                               |                                                    |Snowflake, Inc.  (SNOW )                            |
# |                               |                                                    |Q3 2024 Earnings Call    Snowflake, Inc.  (SNOW )   |
# |                               |                                                    |Q3 2024 Earnings Call  Corrected Transcript         |
# |                               |                                                    |29-Nov-2023                                         |
# |                               |                                                    |                                                    |
# |                               |                                                    |1-877-FACTSET   www.callstreet.com   2              |
# |                               |                                                    |Copyright © 2001 -2023  FactSet  CallStreet, LLC    |
# |                               |                                                    |                                                    |
# |                               |                                                    |                                                    |
# |                               |                                                    |CORPORATE PARTICIPANTS                              |
# |                               |                                                    |                                                    |
# |                               |                                                    |Jimmy L. Sexton                                     |
# |                               |                                                    |Senior Finance Director & Head -Investor Relati...  |
# |                               |                                                    |Frank Slootman                                      |
# |                               |                                                    |Chairman & Chief Executive Officer, Snowflake, ...  |
# |                               |                                                    |Chief Financial Officer, Snowflake, Inc.            |
# |                               |                                                    |Christian Kleinerman                                |
# |                               |                                                    |Senior Vice President -Product, Snowflake, Inc.     |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |                                                    |
# |                               |                                                    |OTHER PARTICIPANTS                                  |
# |                               |                                                    |                                                    |
# |                               |                                                    |Mark R. Murphy                                      |
# |                               |                                                    |Analyst, JPMorgan Securities LLC                    |
# |                               |                                                    |Raimo Lenschow                                      |
# |                               |                                                    |Analyst, Barclays Capital, Inc.                     |
# |                               |                                                    |Kirk Materne                                        |
# |                               |                                                    |Analyst, Evercore ISI                               |
# |                               |                                                    |Brad Reback                                         |
# |                               |                                                    |Analyst, Stifel, Nicolaus & Co., Inc.               |
# |                               |                                                    |Ethan Bruck                                         |
# |                               |                                                    |Analyst, Wolfe Research LLC                         |
# |                               |                                                    |Brent Thill                                         |
# |                               |                                                    |Analyst, Jefferies LLC                              |
# |                               |                                                    |Patrick Colville                                    |
# |                               |                                                    |Analyst, Scotiabank                                 |
# |                               |                                                    |Tyler Radke                                         |
# |                               |                                                    |Analyst, Citigroup Global Markets, Inc.  Brent ...  |
# |                               |                                                    |Analyst, Piper Sandler & Co.                        |
# |                               |                                                    |Derrick Wood                                        |
# |                               |                                                    |Analyst, TD Cowen                                   |
# |                               |                                                    |Joel P. Fishbein                                    |
# |                               |                                                    |Analyst, Truist Securities, Inc.                    |
# |                               |                                                    |Mike Cikos                                          |
# |                               |                                                    |Analyst, Needham & Co. LLC                          |
# |                               |                                                    |Owen Hobbs                                          |
# |                               |                                                    |Analyst, JMP Securities LLC                         |
# |                               |                                                    |Gregg Moskowitz                                     |
# |                               |                                                    |Analyst, Mizuho Securities USA LLC                  |
# |                               |                                                    |William V. Power                                    |
# |                               |                                                    |Analyst, Robert W. Baird & Co., Inc.                |
# |                               |                                                    |  Snowflake, Inc.  (SNOW )                          |
# |                               |                                                    |Q3 2024 Earnings Call  Corrected Transcript         |
# |                               |                                                    |29-Nov-2023                                         |
# |                               |                                                    |                                                    |
# |                               |                                                    |1-877-FACTSET   www.callstreet.com   3              |
# |                               |                                                    |Copyright © 2001 -2023  FactSet  CallStreet, LLC    |
# |                               |                                                    |                                                    |
# |                               |                                                    |                                                    |
# |                               |                                                    |MANAGEMENT DISCUSSION SECTION                       |
# |                               |                                                    |                                                    |
# |                               |                                                    |Operator : Good afternoon. Thank you for attend...  |
# |                               |                                                    |My name is Hannah and I will be your moderator ...  |
# |                               |                                                    |portion of the call, with an opportunity for qu...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |I would now like to pass the conference over to...  |
# |                               |                                                    |You may go ahead.                                   |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |Jimmy L. Sexton                                     |
# |                               |                                                    |Senior Finance Director & Head -Investor Relati...  |
# |                               |                                                    |Good afternoon and thanks for joining us on Sno...  |
# |                               |                                                    |Montana are Frank Slootman, our Chairman and Ch...  |
# |                               |                                                    |Officer; and Christian Kleinerman, our Senior V...  |
# |                               |                                                    |During today's call, we will review our financi...  |
# |                               |                                                    |for the fourth quarter and full year fiscal 202...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |During today's call, we will make forward -look...  |
# |                               |                                                    |performance of our business, future financial r...  |
# |                               |                                                    |repurchase program and overall future prospects...  |
# |                               |                                                    |could cause them to differ materially from actu...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |Information concerni ng those risks is availabl...  |
# |                               |                                                    |and in our SEC filings, including our most rece...  |
# |                               |                                                    |the Form 10 -Q for the quarter ended October 31...  |
# |                               |                                                    |undue reliance on forward -looking statements a...  |
# |                               |                                                    |statements as a result of new information, futu...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |We'd also like to point out that on today's cal...  |
# |                               |                                                    |non-GAAP financial measures internally for fina...  |
# |                               |                                                    |to evaluate period -to-period comparisons. Non ...  |
# |                               |                                                    |a substitute for, financial measures calculated...  |
# |                               |                                                    |GAAP financial measures, please refer to our ea...  |
# |                               |                                                    |presentation, which are posted at investors.sno...  |
# |                               |                                                    |website.                                            |
# |                               |                                                    |                                                    |
# |                               |                                                    |With that, I would now like to turn the call ov...  |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |Frank Slootman                                      |
# |                               |                                                    |Cha irman & Chief Executive Officer, Snowflake,...  |
# |                               |                                                    |Thanks, Jimmy. Welcome and good afternoon. Q3 p...  |
# |                               |                                                    |million. Non -GAAP adjusted free cash flow was ...  |
# |                               |                                                    |reflect strong execution in a broadly stabilizi...  |
# |                               |                                                    |highly diverse in terms of industries and geogr...  |
# |                               |                                                    |mainstream enterprises and institutio ns. This,...  |
# |                               |                                                    |Q3 2024 Earnings Call  Corrected Transcript         |
# |                               |                                                    |29-Nov-2023                                         |
# |                               |                                                    |                                                    |
# |                               |                                                    |1-877-FACTSET   www.callstreet.com   4              |
# |                               |                                                    |Copyright © 2001 -2023  FactSet  CallStreet, LLC    |
# |                               |                                                    |                                                    |
# |                               |                                                    |many of Snowflake's early adopters. We added 35...  |
# |                               |                                                    |customers grew sequentially.                        |
# |                               |                                                    |                                                    |
# |                               |                                                    |Generative AI is at the forefront of customer  ...  |
# |                               |                                                    |strategy in preparation of these new technologi...  |
# |                               |                                                    |strategy. The intelligence we're all aiming for...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |Meanwhile, Snowflake has announced and showcase...  |
# |                               |                                                    |AI. We've introduced Snowflake Cortex to levera...  |
# |                               |                                                    |service for inferencing large language models. ...  |
# |                               |                                                    |like translation, sentiment and vector function...  |
# |                               |                                                    |functionality without the fractured high ly tec...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |Last summer, we introduced Snowpark Container S...  |
# |                               |                                                    |enablement strategy. Developers can access any ...  |
# |                               |                                                    |governance boundary of Snowflake. More than 70 ...  |
# |                               |                                                    |with many more waiting in line. Snowflake makes...  |
# |                               |                                                    |as possible. We are well -positioned for AI bas...  |
# |                               |                                                    |governance framework.                               |
# |                               |                                                    |                                                    |
# |                               |                                                    |There are hurdles challenging enterprise adopti...  |
# |                               |                                                    |Snowflake addresses this challenge through its ...  |
# |                               |                                                    |from 22% a year ago, and 73% of our $1 million ...  |
# |                               |                                                    |models can only be as smart as the data they ar...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |Security and governance present anothe r challe...  |
# |                               |                                                    |offers a unified security and governance soluti...  |
# |                               |                                                    |privileges on data across use cases, including ...  |
# |                               |                                                    |hoc queries.                                        |
# |                               |                                                    |                                                    |
# |                               |                                                    |As part of Horizon, we introduced Universal Sea...  |
# |                               |                                                    |Customers can now discover data and metadata th...  |
# |                               |                                                    |Marketplace.                                        |
# |                               |                                                    |                                                    |
# |                               |                                                    |Snowflake continues to win new workloads outsid...  |
# |                               |                                                    |quarter -over-quarter. Consumption in October w...  |
# |                               |                                                    |Snowflake to process unstructured  data in Octo...  |
# |                               |                                                    |year.                                               |
# |                               |                                                    |                                                    |
# |                               |                                                    |Our newest streaming capability, Dynamic Tables...  |
# |                               |                                                    |customers are using the feature and additional ...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |We have a number of major new capabilities beco...  |
# |                               |                                                    |GA, Unistore, for transaction processing. Snowp...  |
# |                               |                                                    |public p review. These products unlock substant...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |We are campaigning globally to expand our audie...  |
# |                               |                                                    |worldwide in -person attendance at these events...  |
# |                               |                                                    |Q3 2024 Earnings Call  Corrected Transcript         |
# |                               |                                                    |29-Nov-2023                                         |
# |                               |                                                    |                                                    |
# |                               |                                                    |1-877-FACTSET   www.callstreet.com   5              |
# |                               |                                                    |Copyright © 2001 -2023  FactSet  CallStreet, LLC    |
# |                               |                                                    |                                                    |
# |                               |                                                    |BUILD Developer Conference in early December, w...  |
# |                               |                                                    |building apps, data pipelines and AI/ML workflo...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |With that, I will turn th e call over to Mike.      |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |Michael P. Scarpelli                                |
# |                               |                                                    |Chief Financial Officer, Snowflake, Inc.            |
# |                               |                                                    |Thank you, Frank. In Q3, we saw strong consumpt...  |
# |                               |                                                    |evenly split between large and small accounts. ...  |
# |                               |                                                    |growth in Q3. Our two fastest -growing customer...  |
# |                               |                                                    |these accounts is in their second year on the p...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |We added four customers with more than $5 milli...  |
# |                               |                                                    |month product revenue in the quarter. Growth in...  |
# |                               |                                                    |consumption grew faster than any other period i...  |
# |                               |                                                    |month of October. Q3 represented a strong quart...  |
# |                               |                                                    |grew 23% year -over-year to $3.7 billion. Of th...  |
# |                               |                                                    |in the next 12 months. APJ and SMB drove growth...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |We are making significant progress in deliverin...  |
# |                               |                                                    |up approximately 300 basis points year -over-ye...  |
# |                               |                                                    |contributed to margin expansion. We also benefi...  |
# |                               |                                                    |Snowflake. In Q3, price per credit increased 4%...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |Non-GAAP operating margin of 10% was ahea d of ...  |
# |                               |                                                    |outperformance and increased hiring scrutiny. N...  |
# |                               |                                                    |from favorable timing of collections.               |
# |                               |                                                    |                                                    |
# |                               |                                                    |We ended the quarter with $4.5 billion in cash,...  |
# |                               |                                                    |strong cash position allows us to opportunistic...  |
# |                               |                                                    |2.6 million shares. Year -to-date, we have used...  |
# |                               |                                                    |of $147.50.                                         |
# |                               |                                                    |                                                    |
# |                               |                                                    |Now, let's turn to guidance. For the fourth qua...  |
# |                               |                                                    |million, representing year -over-year growth be...  |
# |                               |                                                    |approximately $2.65 billion, representing 37% y...  |
# |                               |                                                    |are seeing stability in customer expansion patt...  |
# |                               |                                                    |continued stability of consumption. F or the fo...  |
# |                               |                                                    |diluted weighted average shares outstanding.        |
# |                               |                                                    |                                                    |
# |                               |                                                    |For the full year, we are increasing our non -G...  |
# |                               |                                                    |gross margin of 77%. We still expe ct a product...  |
# |                               |                                                    |products. We are increasing our fiscal 2024 non...  |
# |                               |                                                    |operating margin of 7%. We are increasing our f...  |
# |                               |                                                    |expect non -GAAP adjusted free cash flow margin...  |
# |                               |                                                    |shares outstanding of 361 million. We are on tr...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |With that, operator, you can now open up the li...  |
# |                               |                                                    |Q3 2024 Earnings Call  Corrected Transcript         |
# |                               |                                                    |29-Nov-2023                                         |
# |                               |                                                    |                                                    |
# |                               |                                                    |1-877-FACTSET   www.callstreet.com   6              |
# |                               |                                                    |Copyright © 2001 -2023  FactSet  CallStreet, LLC    |
# |                               |                                                    |                                                    |
# |                               |                                                    |                                                    |
# |                               |                                                    |QUESTION AND ANSWER SECTION                         |
# |                               |                                                    |                                                    |
# |                               |                                                    |Operator : Absolutely. [Operator Instructions] ...  |
# |                               |                                                    |Please proceed.                                     |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |Mark R. Murphy                                      |
# |                               |                                                    |Analyst, JPMorgan Securities LLC  Q                 |
# |                               |                                                    |Thank you so much. I love the 11 -minute earnin...  |
# |                               |                                                    |hearing broadly that conversations are starting...  |
# |                               |                                                    |their data estat es aren't in good enough shape...  |
# |                               |                                                    |that Snowflake might be on the front edge of AI...  |
# |                               |                                                    |conversations or drive more pipeline for some o...  |
# |                               |                                                    |sharing?                                            |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |Frank Slootman                                      |
# |                               |                                                    |Chairman & Chief Executive Officer, Snowflake, ...  |
# |                               |                                                    |Generally speaking, yes. One of the interesting...  |
# |                               |                                                    |data estate s because they have to get them int...  |
# |                               |                                                    |technologies, which we are now also showcasing ...  |
# |                               |                                                    |governed frameworks to run them with all the th...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |So, it's definitely true that the frenzy and th...  |
# |                               |                                                    |data strategy, data platforms. And people are a...  |
# |                               |                                                    |optimization, organization, curation of data, b...  |
# |                               |                                                    |people are taking a much broader view of their ...  |
# |                               |                                                    |it.                                                 |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |Mark R. Murphy                                      |
# |                               |                                                    |Analyst, JPMorgan Securities LLC  Q                 |
# |                               |                                                    |Thank you very much.                                |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |                                                    |
# |                               |                                                    |Operator : Thank you, Mr. Murphy. Our next ques...  |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |                                                    |
# |                               |                                                    | Q                                                  |
# |                               |                                                    |Great. Thank you. [indiscernible] (13:22) on fo...  |
# |                               |                                                    |mentioned several times on the call the stabili...  |
# |                               |                                                    |heard that from sort of your hyperscaler peers ...  |
# |                               |                                                    |some idea like how much of the stabilization is...  |
# |                               |                                                    |existing customers who [indiscernible] (13:50) ...  |
# |                               |                                                    |new product ? Is there any way that you can kin...  |
# |                               |                                                    |which are yet to come maybe into next year?         |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |Q3 2024 Earnings Call  Corrected Transcript         |
# |                               |                                                    |29-Nov-2023                                         |
# |                               |                                                    |                                                    |
# |                               |                                                    |1-877-FACTSET   www.callstreet.com   7              |
# |                               |                                                    |Copyright © 2001 -2023  FactSet  CallStreet, LLC    |
# |                               |                                                    |                                                    |
# |                               |                                                    |Frank Slootman                                      |
# |                               |                                                    |Chairman & Chief Executive Officer, Snowflake, ...  |
# |                               |                                                    |Keith, one of the things – this is Frank – what...  |
# |                               |                                                    |to include much larger enterprises and institut...  |
# |                               |                                                    |expansion that they then later have to reset an...  |
# |                               |                                                    |and optimizations that we saw earlier in the ye...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |Secondly, people have really driven themselves ...  |
# |                               |                                                    |now in a good place to move forward. You can on...  |
# |                               |                                                    |diminishing returns. People get tired of us and...  |
# |                               |                                                    |namely preparing for enabling AI  and ML techno...  |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |Michael P. Scarpelli                                |
# |                               |                                                    |Chief Financial Officer, Snowflake, Inc.  A         |
# |                               |                                                    |Yeah. I'll add to that, too, that why we see th...  |
# |                               |                                                    |sequentially. And the other point I'll make is ...  |
# |                               |                                                    |mature enterprises we're seeing now, and mature...  |
# |                               |                                                    |so, there's nothing new there, and that will co...  |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |                                                    |
# |                               |                                                    | Q                                                  |
# |                               |                                                    |Got it. That's helpful. And then maybe one quic...  |
# |                               |                                                    |noticed it's basically flat quarter -over-quart...  |
# |                               |                                                    |shed some light in terms of like what regions a...  |
# |                               |                                                    |any sort of areas that you're investing in stil...  |
# |                               |                                                    |color on  where you're investing versus not wou...  |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |Michael P. Scarpelli                                |
# |                               |                                                    |Chief Financial Officer, Snowflake, Inc.  A         |
# |                               |                                                    |Yeah. So first of all, in general, with sales a...  |
# |                               |                                                    |of Q4 or even more  so at the beginning of Q1, ...  |
# |                               |                                                    |say is we are continuing to invest very heavily...  |
# |                               |                                                    |talked about six months ago or so, we added a n...  |
# |                               |                                                    |investing, and we're continuing to and we will ...  |
# |                               |                                                    |right people as we go forward. And APJ is anoth...  |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |                                                    |
# |                               |                                                    | Q                                                  |
# |                               |                                                    |Excellent. Thank you.                               |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |                                                    |
# |                               |                                                    |Operator : Thank you. Mr. Weiss. Our next quest...  |
# |                               |                                                    |proceed.                                            |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |Raimo Lenschow                                      |
# |                               |                                                    |Analyst, Barclays Capital, Inc.  Q Snowflake, I...  |
# |                               |                                                    |Q3 2024 Earnings Call  Corrected Transcript         |
# |                               |                                                    |29-Nov-2023                                         |
# |                               |                                                    |                                                    |
# |                               |                                                    |1-877-FACTSET   www.callstreet.com   8              |
# |                               |                                                    |Copyright © 2001 -2023  FactSet  CallStreet, LLC    |
# |                               |                                                    |                                                    |
# |                               |                                                    |Thank you. Congrats from me as well. Guys, you ...  |
# |                               |                                                    |How do you think about the sales setup here now...  |
# |                               |                                                    |of different areas from classic data to kind of...  |
# |                               |                                                    |Frank, here going forward? And it doesn't sound...  |
# |                               |                                                    |Like how are you going to do that going forward...  |
# |                               |                                                    |market? Than k you.                                 |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |Frank Slootman                                      |
# |                               |                                                    |Chairman & Chief Executive Officer, Snowflake, ...  |
# |                               |                                                    |Yeah. There's actually – that's actually an exc...  |
# |                               |                                                    |selling motion that we sort of deployed everywh...  |
# ...
# |                               |                                                    |tech to mature and evolve deployment architectu...  |
# |                               |                                                    |that these are the right  ways to do it. So, yo...  |
# |                               |                                                    |testing all these kinds of things. And they're ...  |
# |                               |                                                    |And I think that the field will become very pro...  |
# |                               |                                                    |sector specialized models that are very, very, ...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |So, it's going to become an enormous field. I w...  |
# |                               |                                                    |people are looking for a reset of economics, li...  |
# |                               |                                                    |chain management, I mean, really, very, very bi...  |
# |                               |                                                    |things and that has the attention. Data has alw...  |
# |                               |                                                    |influence of the newer technologies that we're ...  |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |Gregg Moskowitz                                     |
# |                               |                                                    |Analyst, Mizuho Securities USA LLC  Q               |
# |                               |                                                    |Very helpful. Thanks. And then  for Mike, reall...  |
# |                               |                                                    |grew faster than any other period over the past...  |
# |                               |                                                    |particularly strong consumption? Was that post ...  |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |Michael P. Scarpelli                                |
# |                               |                                                    |Chief Financial Officer, Snowflake, Inc.  A         |
# |                               |                                                    |It's post -Labor Day.                               |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |Q3 2024 Earnings Call  Corrected Transcript         |
# |                               |                                                    |29-Nov-2023                                         |
# |                               |                                                    |                                                    |
# |                               |                                                    |1-877-FACTSET   www.callstreet.com   18             |
# |                               |                                                    |Copyright © 2001 -2023  FactSet  CallStreet, LLC    |
# |                               |                                                    |                                                    |
# |                               |                                                    |Gregg Moskowitz                                     |
# |                               |                                                    |Analyst, Mizuho Securities USA LLC  Q               |
# |                               |                                                    |All right. Perfect. Thank you.                      |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |                                                    |
# |                               |                                                    |Operator : Thank you, Mr. Moskowitz. Our last q...  |
# |                               |                                                    |proceed.                                            |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |William V. Power                                    |
# |                               |                                                    |Analyst, Robert W. Baird & Co., Inc.  Q             |
# |                               |                                                    |Okay, great. Thanks. Mike, you referenced that ...  |
# |                               |                                                    |over-quarter. I g uess I wonder were there any ...  |
# |                               |                                                    |that? Any other color behind the strength there?    |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |Michael P. Scarpelli                                |
# |                               |                                                    |Chief Financial Officer, Snowflake, Inc.  A         |
# |                               |                                                    |No, these are just all very large customers wit...  |
# |                               |                                                    |migration, but the others are just continuing t...  |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |Frank Slootman                                      |
# |                               |                                                    |Chairman & Chief Executive Officer, Snowflake, ...  |
# |                               |                                                    |Very industry -specific as well.                    |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |William V. Power                                    |
# |                               |                                                    |Analyst, Robert W. Baird & Co., Inc.  Q             |
# |                               |                                                    |Okay. And maybe just a quick question on produc...  |
# |                               |                                                    |your longer -term target, I think. It sounds li...  |
# |                               |                                                    |the general level to expect going forward? And ...  |
# |                               |                                                    |given it seems like you've gotten there faster ...  |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |Michael P. Scarpelli                                |
# |                               |                                                    |Chief Financial Offi cer, Snowflake, Inc.  A        |
# |                               |                                                    |Yeah. I don't really see a lot of upside in our...  |
# |                               |                                                    |that we're seeing this quarter to our margin is...  |
# |                               |                                                    |have  to start to amortize the costs associated...  |
# |                               |                                                    |capitalize under GAAP that are now going to sta...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |In particular, something like Unistore, a lot o...  |
# |                               |                                                    |have negative contribution margins until it tak...  |
# |                               |                                                    |the software to get the – to take costs out of ...  |
# |                               |                                                    |products that are coming out this quarter that ...  |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    |William V. Power                                    |
# |                               |                                                    |Analyst, Robert W. Baird & Co., Inc.  Q             |
# |                               |                                                    |That's helpful. Thank you.                          |
# |                               |                                                    | ................................ ................  |
# |                               |                                                    | Snowflake, Inc.  (SNOW )                           |
# |                               |                                                    |Q3 2024 Earnings Call  Corrected Transcript         |
# |                               |                                                    |29-Nov-2023                                         |
# |                               |                                                    |                                                    |
# |                               |                                                    |1-877-FACTSET   www.callstreet.com   19             |
# |                               |                                                    |Copyright © 2001 -2023  FactSet  CallStreet, LLC    |
# |                               |                                                    |                                                    |
# |                               |                                                    |Operator : Thank you, Mr. Power. That concludes...  |
# |                               |                                                    |Thank you for your participation. You may now d...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |                                                    |
# |                               |                                                    |                                                    |
# |                               |                                                    |                                                    |
# |                               |                                                    |                                                    |
# |                               |                                                    |                                                    |
# |                               |                                                    |                                                    |
# |                               |                                                    |                                                    |
# |                               |                                                    |                                                    |
# |                               |                                                    |                                                    |
# |                               |                                                    |                                                    |
# |                               |                                                    |Disclaimer                                          |
# |                               |                                                    |The information herein is based on sources we b...  |
# |                               |                                                    |As such, we do not warrant, endorse or guarante...  |
# |                               |                                                    |information provided hereunder, including any r...  |
# |                               |                                                    |of investment decisions. It should not be c ons...  |
# |                               |                                                    |not to be construed as financial or other advic...  |
# |                               |                                                    |information expressed herein on this date is su...  |
# |                               |                                                    |CallStreet, LLC. FactSet CallStreet, LLC, or on...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |THE INFORMATION PROVIDED TO YOU HEREUNDER IS PR...  |
# |                               |                                                    |BUSINESS ASSOCIATES AND SUPPLIERS DISCLAIM ALL ...  |
# |                               |                                                    |WARRANTIES OF MERCHANTABILITY, FITNESS FOR A PA...  |
# |                               |                                                    |LAW, NEITHER FACTSET CALLSTREET, LLC NOR ITS OF...  |
# |                               |                                                    |INDIRECT, INCIDENTAL, SPECIAL, CONSEQUENTIAL OR...  |
# |                               |                                                    |SECURITY BREACHES, VIRUSES, CO MPUTER FAILURE O...  |
# |                               |                                                    |OF THE POSSIBILITY OF SUCH LOSSES, ARISING UNDE...  |
# |                               |                                                    |                                                    |
# |                               |                                                    |The contents and appearance of this report are ...  |
# |                               |                                                    |other trademarks mentioned are trademarks of th...  |
# -------------------------------------------------------------------------------------------------------------------------------------------

# %%
class text_chunker:

    def process(self, text):
        text_raw = []
        text_raw.append(text)

        text_splitter = RecursiveCharacterTextSplitter(
            separators=[
                "\n"
            ],  # Define an appropriate separator. New line is good typically!
            chunk_size=500,  # Adjust this as you see fit
            chunk_overlap=100,  # This let's text have some form of overlap. Useful for keeping chunks contextual
            length_function=len,
            add_start_index=True,  # Optional but useful if you'd like to feed the chunk before/after
        )

        chunks = text_splitter.create_documents(text_raw)
        df = pd.DataFrame(chunks, columns=["chunks", "meta"])

        yield from df.itertuples(index=False, name=None)

# %%
# Register the UDTF

schema = StructType(
    [
        StructField("chunk", StringType()),
        StructField("meta", StringType()),
    ]
)

session.udtf.register(
    handler=text_chunker,
    output_schema=schema,
    input_types=[StringType()],
    is_permanent=True,
    name="CHUNK_TEXT",
    replace=True,
    packages=["pandas", "langchain"],
    stage_location="RAG",
)

# %%
session.sql(
    """
CREATE OR REPLACE TABLE CHUNK_TEXT AS
SELECT
        relative_path,
        func.*
    FROM raw_text AS raw,
         TABLE(chunk_text(raw_text)) as func;
            """
).collect()
# Out:
# [Row(status='Table CHUNK_TEXT successfully created.')]

# %% [markdown]
# Move on to the .sql file or you can write these in a Snowflake Notebook

# %%
session.file.put("images/*", "@rag_images")
# Out:
# [PutResult(source='Chunk.text.png', target='Chunk.text.png.gz', source_size=227474, target_size=202880, source_compression='NONE', target_compression='GZIP', status='UPLOADED', message=''),
#  PutResult(source='Embed_text.png', target='Embed_text.png.gz', source_size=243717, target_size=220240, source_compression='NONE', target_compression='GZIP', status='UPLOADED', message=''),
#  PutResult(source='Extract_Text.png', target='Extract_Text.png.gz', source_size=127844, target_size=104336, source_compression='NONE', target_compression='GZIP', status='UPLOADED', message=''),
#  PutResult(source='RAG_Arch.png', target='RAG_Arch.png.gz', source_size=83036, target_size=77968, source_compression='NONE', target_compression='GZIP', status='UPLOADED', message=''),
#  PutResult(source='embedding_functions.png', target='embedding_functions.png.gz', source_size=88266, target_size=81152, source_compression='NONE', target_compression='GZIP', status='UPLOADED', message=''),
#  PutResult(source='rag_query.png', target='rag_query.png.gz', source_size=87799, target_size=83552, source_compression='NONE', target_compression='GZIP', status='UPLOADED', message=''),
#  PutResult(source='sis.png', target='sis.png.gz', source_size=114036, target_size=107904, source_compression='NONE', target_compression='GZIP', status='UPLOADED', message='')]
